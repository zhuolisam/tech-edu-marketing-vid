# %%
#Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Why do we need to drop features?
# 1. Redundant features
# 2. Irrelevant features
# 3. Features with low variance
# 4. Features with high correlation
#
# These features/columns does not help in model training.

# %%
#import dataset
df = pd.read_csv('../Data/titanic.csv')
df.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1       No       3
# 1            2      Yes       1
# 2            3      Yes       3
# 3            4      Yes       1
# 4            5       No       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Name and Ticket number are not useful for our analysis, we cn drop them
df.drop(['PassengerId','Name', 'Ticket'], axis=1, inplace=True)
df.head()
# Out:
#   Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0       No       3    male  22.0      1      0   7.2500   NaN        S
# 1      Yes       1  female  38.0      1      0  71.2833   C85        C
# 2      Yes       3  female  26.0      0      0   7.9250   NaN        S
# 3      Yes       1  female  35.0      1      0  53.1000  C123        S
# 4       No       3    male  35.0      0      0   8.0500   NaN        S
