# %%
#Import libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#create sample data
age = [10,35,12,45,35,10,12,10,26,35,10]
score = [916, 1196, 820, 929, 712, 1024, 775, 819, 728, 967,878]

# %%
# Set the figure size to (12,6)
plt.figure(figsize=(12,6))

#Plot a scatter chart. Scatter chart is useful to show the relationship between two variables
sns.scatterplot(x=age,y=score)
# Out:
# <AxesSubplot:>
